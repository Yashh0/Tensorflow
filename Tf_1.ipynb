# %% [markdown]
# <a href="https://colab.research.google.com/github/Yashh0/Tensorflow/blob/main/Tf_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import tensorflow as tf
from tensorflow import keras
import numpy as np

# %%
model = tf.keras.Sequential([keras.layers.Dense(units=2 , input_shape=[1])])

# %%
model.compile(optimizer = 'sgd' , loss = 'mean_squared_error')

# %%
xs = np.array ([-1.0 , 0.0 , 2.0 , 3.0 , 4.0], dtype = float)
ys = np.array ([-3.0 , -1.0 , 3.0 , 5.0 , 7.0], dtype = float)

# %%
model.fit(xs ,ys , epochs =500)
# Out:
# Epoch 1/500
# 1/1 [==============================] - 0s 323ms/step - loss: 47.2001
# Epoch 2/500
# 1/1 [==============================] - 0s 10ms/step - loss: 41.4929
# Epoch 3/500
# 1/1 [==============================] - 0s 7ms/step - loss: 36.4980
# Epoch 4/500
# 1/1 [==============================] - 0s 8ms/step - loss: 32.1262
# Epoch 5/500
# 1/1 [==============================] - 0s 9ms/step - loss: 28.2995
# Epoch 6/500
# 1/1 [==============================] - 0s 7ms/step - loss: 24.9499
# Epoch 7/500
# 1/1 [==============================] - 0s 7ms/step - loss: 22.0175
# Epoch 8/500
# 1/1 [==============================] - 0s 8ms/step - loss: 19.4501
# Epoch 9/500
# 1/1 [==============================] - 0s 6ms/step - loss: 17.2021
# Epoch 10/500
# 1/1 [==============================] - 0s 9ms/step - loss: 15.2336
# Epoch 11/500
# 1/1 [==============================] - 0s 6ms/step - loss: 13.5095
# Epoch 12/500
# ...

# %%
#make prediction

print(model.predict([10.0]))
# Out:
# 1/1 [==============================] - 0s 69ms/step
# [[18.768679 18.7643  ]]
